# %%
# This information helps with debugging and getting support :)
import sys, platform
import pandas as pd
import numpy as np
import bifacial_radiance as br
print("Working on a ", platform.system(), platform.release())
print("Python version ", sys.version)
print("Pandas version ", pd.__version__)
print("bifacial_radiance version ", br.__version__)
# Out:
# Working on a  Windows 11
# Python version  3.13.9 | packaged by conda-forge | (main, Oct 22 2025, 23:12:41) [MSC v.1944 64 bit (AMD64)]
# Pandas version  2.3.3
# bifacial_radiance version  0.5.0

# %%
import os
import time
from pathlib import Path
import pandas as pd

testfolder = 'TEMP'

# Another option using relative address; for some operative systems you might need '/' instead of '\'
# testfolder = os.path.abspath(r'..\..\bifacial_radiance\TEMP')  

print ("Your simulation will be stored in %s" % testfolder)

if not os.path.exists(testfolder):
    os.makedirs(testfolder)
# Out:
# Your simulation will be stored in TEMP

# %%
# add _popen functionality

from subprocess import Popen, PIPE  # replacement for os.system()

def _popen(cmd, data_in, data_out=PIPE):
    """
    Helper function subprocess.popen replaces os.system
    - gives better input/output process control
    usage: pass <data_in> to process <cmd> and return results
    based on rgbeimage.py (Thomas Bleicher 2010)
    """
    if isinstance(cmd, str):
        cmd = str(cmd)  # gets rid of unicode oddities
        shell = True
    else:
        shell = False
    # shell=True required for Linux? quick fix, but may be security concern
    p = Popen(cmd, bufsize=-1, stdin=PIPE, stdout=data_out, stderr=PIPE, shell=shell) 
    data, err = p.communicate(data_in)

    if err:
        if data:
            returntuple = (data.decode('latin1'), 'message: '+err.decode('latin1').strip())
        else:
            returntuple = (None, 'message: '+err.decode('latin1').strip())
    else:
        if data:
            returntuple = (data.decode('latin1'), None)  # Py3 requires decoding
        else:
            returntuple = (None, None)

    return returntuple

# %%
demo = br.RadianceObj('tutorial_1',str(testfolder))  
epwfile = demo.getEPW(lat = 37.5, lon = -77.6)  # This location corresponds to Richmond, VA.
# Out:
# path = TEMP
# Getting weather file: USA_VA_Richmond.724010_TMY2.epw
#  ... OK!

# %%
# !epw2wea .\EPWs\USA_VA_Richmond.724010_TMY2.epw .\EPWs\USA_VA_Richmond.724010_TMY2.wea

# %%
metdata = demo.readWeatherFile(epwfile, coerce_year=2001)
# Out:
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos

# %% [markdown]
# ![image.png](attachment:e57360e2-c0b9-420c-be24-baea92d4ed87.png)

# %% [markdown]
# ![image.png](attachment:5120dea9-77a5-4ecf-8299-79877355a93e.png)

# %%
demo.setGround(0.2)
demo.genCumSky() # entire year.
# Out:
# Loading albedo, 1 value(s), 0.200 avg
# 1 nonzero albedo values.
# Loaded  EPWs\metdata_temp.csv
# message: Error!  Solar altitude is -7 < -6 degrees and Idh = 13 > 10 W/m^2 on day 76 !Ibn is 0.  Attempting to continue!
# Error!  Solar altitude is -7 < -6 degrees and Idh = 11 > 10 W/m^2 on day 78 !Ibn is 0.  Attempting to continue!
# Error!  Solar altitude is -6 < -6 degrees and Idh = 14 > 10 W/m^2 on day 81 !Ibn is 0.  Attempting to continue!
# There were 4537 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# 'skies\\cumulative.rad'

# %% [markdown]
# ![image.png](attachment:f0f2119d-8d36-4dd7-91bc-8d02bc1453c2.png)

# %% [markdown]
# ![image.png](attachment:142c7b14-b0bc-4b33-b410-a9a4a76726ae.png)

# %%
# visible wavelengths only - not what we want...
# !gendaymtx -m 1 -A -h .\EPWs\USA_VA_Richmond.724010_TMY2.wea > .\EPWs\visible_results.mtx
# Out:
# gendaymtx: warning - unusually bright at 17.5 on 1-14
# gendaymtx: warning - unusually bright at 17.5 on 1-17
# gendaymtx: warning - unusually bright at 17.5 on 1-19
# gendaymtx: warning - unusually bright at 17.5 on 1-22
# gendaymtx: warning - unusually bright at 17.5 on 1-27
# gendaymtx: warning - unusually bright at 17.5 on 1-28
# gendaymtx: warning - unusually bright at 17.5 on 1-31
# gendaymtx: warning - unusually bright at 17.5 on 2-1
# gendaymtx: warning - unusually bright at 17.5 on 2-2
# gendaymtx: warning - unusually bright at 6.5 on 3-6
# gendaymtx: warning - unusually bright at 6.5 on 3-7
# gendaymtx: warning - unusually bright at 18.5 on 3-8
# gendaymtx: warning - unusually bright at 6.5 on 3-10
# gendaymtx: warning - unusually bright at 6.5 on 3-11
# gendaymtx: warning - unusually bright at 18.5 on 3-18
# gendaymtx: warning - unusually bright at 18.5 on 3-19
# gendaymtx: warning - unusually bright at 18.5 on 3-22
# gendaymtx: warning - unusually bright at 18.5 on 3-26
# gendaymtx: warning - unusually bright at 18.5 on 3-27
# gendaymtx: warning - unusually bright at 18.5 on 3-30
# gendaymtx: warning - unusually bright at 18.5 on 4-2
# gendaymtx: warning - unusually bright at 18.5 on 4-4
# gendaymtx: warning - unusually bright at 5.5 on 4-11
# gendaymtx: warning - unusually bright at 5.5 on 4-19
# gendaymtx: warning - unusually bright at 5.5 on 4-20
# gendaymtx: warning - unusually bright at 19.5 on 7-7
# gendaymtx: warning - unusually bright at 19.5 on 7-8
# gendaymtx: warning - unusually bright at 19.5 on 7-12
# gendaymtx: warning - unusually bright at 19.5 on 7-13
# gendaymtx: warning - unusually bright at 19.5 on 7-25
# gendaymtx: warning - unusually bright at 5.5 on 8-27
# gendaymtx: warning - unusually bright at 18.5 on 9-7
# gendaymtx: warning - unusually bright at 18.5 on 9-8
# gendaymtx: warning - unusually bright at 17.5 on 10-16
# gendaymtx: warning - unusually bright at 17.5 on 10-17
# gendaymtx: warning - unusually bright at 17.5 on 10-19
# gendaymtx: warning - unusually bright at 17.5 on 10-21
# gendaymtx: warning - unusually bright at 6.5 on 10-22
# gendaymtx: warning - unusually bright at 17.5 on 10-22
# gendaymtx: warning - unusually bright at 6.5 on 10-23
# gendaymtx: warning - unusually bright at 6.5 on 10-24
# gendaymtx: warning - unusually bright at 17.5 on 10-24
# gendaymtx: warning - unusually bright at 6.5 on 10-29
# gendaymtx: warning - unusually bright at 6.5 on 10-30
# gendaymtx: warning - unusually bright at 17.5 on 10-30
# gendaymtx: warning - unusually bright at 6.5 on 10-31
# gendaymtx: warning - unusually bright at 6.5 on 11-1
# gendaymtx: warning - unusually bright at 6.5 on 11-4
# gendaymtx: warning - unusually bright at 6.5 on 11-5
# gendaymtx: warning - unusually bright at 6.5 on 11-6
# gendaymtx: warning - unusually bright at 6.5 on 11-11
# gendaymtx: warning - unusually bright at 6.5 on 11-17

# %% [markdown]
# ![image.png](attachment:64ad4187-0c55-499f-9336-b13a5ef0c58c.png)

# %% [markdown]
# ### other tests of gendaymtx

# %%
# pyradiance equivalent of: gendaymtx -m 1 -A -O1 ./EPWs/... > ./EPWs/totalirrad_results.mtx
import pyradiance

wea_path = os.path.join('EPWs', 'USA_VA_Richmond.724010_TMY2.wea')
out_path = os.path.join('EPWs', 'totalirrad_results.mtx')

#with open(wea_path, 'rb') as f:
#    wea_bytes = f.read()

mtx_bytes = pyradiance.gendaymtx(weather_data=wea_path, 
                                 mfactor=1, average=True,
                                 solar_radiance=True, header=False)  # solar_radiance=True for total irradiance, false for visible only

with open(out_path, 'wb') as f:
    f.write(mtx_bytes)
print(f"Written: {out_path}  ({len(mtx_bytes):,} bytes)")
# Out:
# Written: EPWs\totalirrad_results.mtx  (2,207 bytes)

# %%
# total irradiance, not just visible.  This is the correct output
#!gendaymtx -m 1 -A -O1 .\EPWs\USA_VA_Richmond.724010_TMY2.wea > .\EPWs\totalirrad_results.mtx
cmd = "gendaymtx -m 1 -A -O1 -h ./EPWs/USA_VA_Richmond.724010_TMY2.wea > ./EPWs/totalirrad_results.mtx"
temp_out,err = _popen(cmd,None)
if err is not None:
    if err[0:5] == 'error':
        raise Exception(err[7:])
    #else:
    #    print(err)

# %%
# More patches - not directly transferrable to the M=1 .cal files
#!gendaymtx -m 2 -A -O1 .\EPWs\USA_VA_Richmond.724010_TMY2.wea > .\EPWs\totalirrad_results_m2.mtx
cmd = "gendaymtx -m 2 -A -O1 -h ./EPWs/USA_VA_Richmond.724010_TMY2.wea > ./EPWs/totalirrad_results_m2.mtx"
temp_out,err = _popen(cmd,None)
if err is not None:
    if err[0:5] == 'error':
        raise Exception(err[7:])

# %%
# much larger hourly (not cumulative) file.
#!gendaymtx -m 1 .\EPWs\USA_VA_Richmond.724010_TMY2.wea > .\EPWs\I_think_hourly_results.mtx
cmd = "gendaymtx -m 1 -h ./EPWs/USA_VA_Richmond.724010_TMY2.wea > ./EPWs/I_think_hourly_results.mtx"
temp_out,err = _popen(cmd,None)
if err is not None:
    if err[0:5] == 'error':
        raise Exception(err[7:])

# %% [markdown]
# Perhaps we can compare results from gendaylit to this?
#
# ![image.png](attachment:fdb6fb6f-9df0-4e15-8b75-bc01fbd488d5.png)

# %% [markdown]
# ### Initial standard run for comparison

# %%
module_type = 'test-module' 
module = demo.makeModule(name=module_type,x=2, y=1)
print(module)
# Out:
# Module Name: test-module
# Module test-module updated in module.json
# Pre-existing .rad file objects\test-module.rad will be overwritten
#
# <class 'bifacial_radiance.module.ModuleObj'> : {'x': 2, 'y': 1, 'z': 0.02, 'modulematerial': 'black', 'scenex': np.float64(2.01), 'sceney': np.float64(1.0), 'scenez': np.float64(0.1), 'numpanels': 1, 'bifi': 1, 'text': '! genbox black test-module 2 1 0.02 | xform -t -1.0 -0.5 0 -a 1 -t 0 1.0 0', 'modulefile': 'objects\\test-module.rad', 'glass': False, 'glassEdge': 0.01, 'offsetfromaxis': 0, 'xgap': 0.01, 'ygap': 0.0, 'zgap': 0.1}

# %%
sceneDict = {'tilt':10,'pitch':3,'clearance_height':0.2,'azimuth':180, 'nMods': 20, 'nRows': 7} 

scene = demo.makeScene(module,sceneDict)

# %%
filelist = demo.getfilelist()
filelist
# Out:
# ['materials\\ground.rad',
#  'skies\\cumulative.rad',
#  'objects\\test-module_C_0.20_rtr_3.00_tilt_10_20modsx7rows_origin0,0.rad']

# %%
# time baseline from here

start_time = time.time()
demo.genCumSky() # entire year.
octfile = demo.makeOct(demo.getfilelist())
# Out:
# Loaded  EPWs\metdata_temp.csv
# message: Error!  Solar altitude is -7 < -6 degrees and Idh = 13 > 10 W/m^2 on day 76 !Ibn is 0.  Attempting to continue!
# Error!  Solar altitude is -7 < -6 degrees and Idh = 11 > 10 W/m^2 on day 78 !Ibn is 0.  Attempting to continue!
# Error!  Solar altitude is -6 < -6 degrees and Idh = 14 > 10 W/m^2 on day 81 !Ibn is 0.  Attempting to continue!
# There were 4537 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created tutorial_1.oct

# %%
analysis = br.AnalysisObj(octfile, demo.basename)

# %%
frontscan, backscan = analysis.moduleAnalysis(scene)

# %%
results = analysis.analysis(octfile, demo.basename, frontscan, backscan)
# Out:
# Linescan in process: tutorial_1_Row4_Module10_Front
# Linescan in process: tutorial_1_Row4_Module10_Back
# Saved: results\irr_tutorial_1_Row4_Module10.csv

# %%
print(analysis.Wm2Front)
elapsed_baseline = time.time() - start_time
print(f"Total time: {elapsed_baseline:.2f} seconds")
# Out:
# [1629921. 1630018. 1630132. 1630247. 1630362. 1630476. 1630590. 1633014.
#  1632835.]
# Total time: 94.23 seconds

# %% [markdown]
# https://unmethours.com/question/17628/understanding-radiance-the-relationship-between-sky-conditions-and-irradiance/
# https://www.radiance-online.org/pipermail/radiance-general/2003-October/001059.html

# %% [markdown]
# ![image.png](attachment:1613d371-5547-4fd0-96e1-411bc4cdb7e6.png)

# %% [markdown]
# ## Claude code analysis of the above comparisons:

# %% [markdown]
# ## Output File Comparison: `genCumSky()` vs `gendaymtx`
#
# | File | Command | NROWS | NCOLS | Format | Size |
# |---|---|---|---|---|---|
# | `cumulative.cal` | `genCumSky()` → `gencumulativesky` | 8 altitude bands × azimuth bins | — | Radiance `.cal` function | 3.3 KB |
# | `visible_results.mtx` | `gendaymtx -m 1 -A` | 146 patches | 1 (annual) | sky matrix | 2.4 KB |
# | `totalirrad_results.mtx` | `gendaymtx -m 1 -A -O1` | 146 patches | 1 (annual) | sky matrix | 2.3 KB |
# | `totalirrad_results_m2.mtx` | `gendaymtx -m 2 -A -O1` | 586 patches | 1 (annual) | sky matrix | 8.8 KB |
# | `I_think_hourly_results.mtx` | `gendaymtx -m 1` | 146 patches | 8760 (hourly) | sky matrix | 14.8 MB |
#
# ### Key Findings
#
# **`totalirrad_results.mtx` is the closest equivalent to `genCumSky()`** because:
# - Both are **annual/cumulative** (not hourly)
# - Both use the **Tregenza m=1 sky division** (146 patches)
# - `-O1` selects **total solar irradiance** (full spectrum), matching what bifacial_radiance needs for energy yield calculations
# - `visible_results.mtx` (no `-O1`) uses visible/luminance weighting — **not appropriate** as a drop-in replacement for PV simulation
#
# **`I_think_hourly_results.mtx`** is **not comparable** — `NCOLS=8760` means it stores one sky per hour, not a cumulative sky. It is a completely different data structure used for climate-based daylight modeling with `rfluxmtx`.
#
# **`totalirrad_results_m2.mtx`** has the same total-irradiance/cumulative intent but at higher angular resolution (Reinhart m=2, 586 patches) — compatible for higher-accuracy simulations but not directly interchangeable with the m=1 `.cal` file.
#
# ### Format Difference to Resolve
#
# The `cumulative.cal` is a **Radiance function** (used directly in `oconv`/`rpict` rendering), while the `.mtx` files are **sky matrices** used in the two-phase matrix method (`rfluxmtx`). They represent the same physics but in different pipeline formats.
#
# ### TODO
#
# - [X] Convert `totalirrad_results.mtx` to a `.rad` sky description (e.g. `cumulative_gendaymtx.rad`) so it can be used as a drop-in replacement for `cumulative.cal` in the existing single-phase Radiance pipeline
# - [X] Verify that `oconv` + `rpict`/`rtrace` can consume the converted `.rad` sky and produce equivalent irradiance results to the `genCumSky()` workflow
# - [X] Compare numerical results (front/back irradiance from `analysis.analysis()`) between the two sky generation methods on the same scene
# - [ ] Evaluate whether the higher-resolution `totalirrad_results_m2.mtx` (Reinhart m=2) offers meaningful accuracy improvement for bifacial simulations
# - [ ] Update `bifacial_radiance.genCumSky()` (or add a new method) to call `gendaymtx -m 1 -A -O1` internally once the workflow is validated

# %% [markdown]
# ---
# ## TODO #1: Convert `totalirrad_results.mtx` to a Radiance sky description
#
# **Goal:** Generate `skies/cumulative_gendaymtx.cal` and `skies/cumulative_gendaymtx.rad`
# so the gendaymtx output can be used as a drop-in replacement for `cumulative.cal` in the
# existing single-phase `oconv` → `rtrace` pipeline.
#
# **MTX layout (gendaymtx, Reinhart m=1, NROWS=146):**
# - Row 0: ground patch (spectrally flat; equal R=G=B)
# - Rows 1–30: altitude band 0–12° (30 azimuth patches)
# - Rows 31–60: altitude band 12–24° (30 patches)
# - Rows 61–84: altitude band 24–36° (24 patches)
# - Rows 85–108: altitude band 36–48° (24 patches)
# - Rows 109–126: altitude band 48–60° (18 patches)
# - Rows 127–138: altitude band 60–72° (12 patches)
# - Rows 139–144: altitude band 72–84° (6 patches)
# - Row 145: zenith patch (84–90°, 1 patch)
#
# **Azimuth convention note:** Both gendaymtx and gencumulativesky use the same Radiance
# `az` variable (0°=South, increasing Westward). An offset correction may be needed after
# comparing results — see TODO #3.

# %%
# time from here
import numpy as np
start_time = time.time()

cmd = "gendaymtx -m 1 -A -O1 -h ./EPWs/USA_VA_Richmond.724010_TMY2.wea > ./EPWs/totalirrad_results.mtx"
temp_out,err = _popen(cmd,None)

def convert_to_annual_whm2(text_data):
    """
    Parses Radiance dctimestep output and returns a NumPy array of annual Wh/m^2.
    """
    annual_wh_m2 = []
    
    for line in text_data.strip().split('\n'):
        parts = line.split()
        
        # Data lines will have exactly 3 components (RGB)
        if len(parts) == 3:
            try:
                r, g, b = [float(x) for x in parts]
                
                # 1. Apply Radiance solar weighting (W/m^2)
                w_m2_avg = (0.265 * r) + (0.670 * g) + (0.065 * b)
                
                # 2. Scale from average W/m^2 to annual Wh/m^2
                annual_wh_m2.append(w_m2_avg * 8760)
            except ValueError:
                # Safely skips header lines that might have 3 words
                continue
                
    return np.array(annual_wh_m2)

# If reading directly from the output file:
# with open('final_results.dat', 'r') as f:
#     results_array = convert_to_annual_whm2(f.read())

# %%
import numpy as np

def read_mtx(mtx_file):
    """
    Read a gendaymtx annual cumulative MTX file.
    Returns array of shape (n_patches+1, 3) — one row per patch, columns are R, G, B.
    Row 0 = ground patch; rows 1+ = sky patches (bottom to top).
    Number of sky patches depends on M: M=1 → 145, M=2 → 577, M=4 → 2305.
    """
    with open(mtx_file, 'r') as f:
        lines = f.readlines()
    # Skip header lines until the first blank line. 
    #data_start = next(i + 1 for i, l in enumerate(lines) if l.strip() == '')
    #data_start = 0 # NOTE: running gendaymtx with -h (header=False) mode, the file immediately starts with data...
    data = [list(map(float, l.split())) for l in lines if l.strip()]
    return np.array(data) * 8760  # Multiply by 8760 to convert from average to total

mtx_path = os.path.join('EPWs', 'totalirrad_results.mtx')
patches = read_mtx(mtx_path)

print(f"Patches shape:          {patches.shape}  (should be (n_sky+1) x 3)")
print(f"Row  0 — ground patch:  {patches[0]}  (expect equal R=G=B)")
print(f"Row  1 — lowest sky:    {patches[1]}")
print(f"Row 30 — end of band 0: {patches[30]}")
print(f"Row 31 — start band 1:  {patches[31]}")
print(f"Row -1 — zenith:        {patches[-1]}")
print(f"\nScalar irradiance range (sky patches only): "
      f"{patches[1:].mean(axis=1).min():.2f} – {patches[1:].mean(axis=1).max():.2f}")
# Out:
# Patches shape:          (146, 3)  (should be (n_sky+1) x 3)
# Row  0 — ground patch:  [97236. 97236. 97236.]  (expect equal R=G=B)
# Row  1 — lowest sky:    [169068. 176952. 197100.]
# Row 30 — end of band 0: [170820. 177828. 198852.]
# Row 31 — start band 1:  [148920. 155928. 173448.]
# Row -1 — zenith:        [191844. 200604. 223380.]
#
# Scalar irradiance range (sky patches only): 142496.00 – 1059960.00

# %%
# Tregenza M=1 base band structure — used as the template for all M values
_TREGENZA_BANDS = [
    ( 0, 12, 30, 12.0),
    (12, 24, 30, 12.0),
    (24, 36, 24, 15.0),
    (36, 48, 24, 15.0),
    (48, 60, 18, 20.0),
    (60, 72, 12, 30.0),
    (72, 84,  6, 60.0),
    (84, 90,  1, 360.0),  # zenith — never subdivided
]

def _make_reinhart_bands(M):
    """
    Build the Reinhart sky band structure for subdivision factor M.

    Each non-zenith Tregenza band is split into M altitude sub-bands, each
    with n_az*M azimuth patches and az_step/M degrees per patch.
    The zenith band (n_az==1) is left as a single patch regardless of M.

    Patch counts: M=1 → 145, M=2 → 577 (= M²×144 + 1), M=4 → 2305.
    """
    bands = []
    for alt_lo, alt_hi, n_az, az_step in _TREGENZA_BANDS:
        if n_az == 1:                    # zenith: keep as a single patch
            bands.append((alt_lo, alt_hi, 1, 360.0))
        else:
            sub_range = (alt_hi - alt_lo) / M
            for i in range(M):
                bands.append((
                    alt_lo + i * sub_range,
                    alt_lo + (i + 1) * sub_range,
                    n_az * M,
                    az_step / M,
                ))
    return bands


def mtx_to_cal(patches, M=1, savefile='cumulative_gendaymtx', sky_path='skies'):
    """
    Convert a gendaymtx annual cumulative MTX into a
    gencumulativesky-compatible .cal file.

    Parameters
    ----------
    patches : np.ndarray, shape (n_sky+1, 3)
        Output of read_mtx(). Row 0 = ground; rows 1+ = sky patches.
    M : int
        Reinhart subdivision factor (1 = Tregenza, 2 = Reinhart M=2, etc.)
        Must match the -m value used with gendaymtx.
    savefile : str
        Base filename (no extension).
    sky_path : str
        Directory for output file.

    Band structure: (alt_lo, alt_hi, n_patches, az_step_deg)
    Patches within each band run counterclockwise from az=0 (South).

    NOTE: azimuth offset vs. gencumulativesky needs empirical verification
    using TODO #3 comparison. Adjust `az_offset_deg` if results diverge.
    """
    bands = _make_reinhart_bands(M)
    n_sky_expected = sum(n for _, _, n, _ in bands)

    sky_irr = patches[1:].mean(axis=1)  # scalar irradiance per sky patch
    if sky_irr.shape[0] != n_sky_expected:
        raise ValueError(
            f"patches has {sky_irr.shape[0]} sky rows but M={M} expects {n_sky_expected}. "
            "Check that the MTX file matches the requested M."
        )

    if sky_path:
        os.makedirs(sky_path, exist_ok=True)
        cal_path = os.path.join(sky_path, savefile + '.cal')
    else:
        cal_path = savefile + '.cal'

    n_bands = len(bands)
    row_sum = '+'.join(f"row{i}" for i in range(n_bands))

    with open(cal_path, 'w') as f:
        f.write(f"{{ Generated from gendaymtx -m {M} -A -O1 }}\n\n")
        f.write(f"skybright={row_sum};\n\n")

        patch_idx = 0
        for row_idx, (alt_lo, alt_hi, n, az_step) in enumerate(bands):
            vals = sky_irr[patch_idx: patch_idx + n]
            patch_idx += n

            if n == 1:  # zenith — no azimuth dependency
                f.write(f"row{row_idx}=if(and(alt-{alt_lo}, {alt_hi}-alt),"
                        f"{vals[0]:.6f},0);\n\n")
            else:
                # Append vals[0] at the end as wrap-around guard.
                # When az is near 360°, select() index reaches n+1; the repeated
                # first value matches the genCumSky convention and avoids a
                # "select(): domain error" from rtrace.
                vals_wrap = list(vals) + [vals[0]]
                vals_str = ',\n        '.join(f"{v:.6f}" for v in vals_wrap)
                f.write(f"row{row_idx}=if(and(alt-{alt_lo}, {alt_hi}-alt),"
                        f"select(floor(0.5+az/{az_step:.2f})+1,\n"
                        f"        {vals_str}),0);\n\n")
        f.write("\n\nalt=asin(Dz)*180/PI;\n\naz=if(azi,azi,azi+360);\nazi=atan2(Dx,Dy)*180/PI;\n")
    print(f"Written: {cal_path}  ({patch_idx} sky patches encoded, M={M})")
    return cal_path

cal_path = mtx_to_cal(patches, M=1, sky_path=os.path.join('skies'))
# Out:
# Written: skies\cumulative_gendaymtx.cal  (145 sky patches encoded, M=1)

# %%
def cal_to_rad(cal_path, demo, M=1, savefile='cumulative_gendaymtx'):
    """
    Wrap a .cal file in a Radiance sky .rad description — same template
    as genCumSky() — so it can be passed directly to demo.makeOct().
    """
    sky_path = os.path.dirname(cal_path)

    try:
        groundstring = demo.ground._makeGroundString(cumulativesky=True)
    except Exception as e:
        raise RuntimeError(f"Run demo.setGround() first. Error: {e}")

    skyStr = (
        f"#Cumulative Sky Definition (generated from gendaymtx -m {M} -A -O1)\n"
        "void brightfunc skyfunc\n"
        f"2 skybright {cal_path}\n"
        "0\n"
        "0\n"
        "\nskyfunc glow sky_glow\n"
        "0\n"
        "0\n"
        "4 1 1 1 0\n"
        "\nsky_glow source sky\n"
        "0\n"
        "0\n"
        "4 0 0 1 180\n"
        + groundstring
    )

    rad_path = os.path.join(sky_path, savefile + '.rad')
    with open(rad_path, 'w') as f:
        f.write(skyStr)

    print(f"Written: {rad_path}")
    return rad_path

rad_path = cal_to_rad(cal_path, demo, M=1)
print(f"\nNew sky file ready: {rad_path}")

# Quick sanity check: compare total sky brightness
gendaymtx_total = patches[1:].mean(axis=1).sum()
n_sky = patches.shape[0] - 1
print(f"\nTotal cumulative sky irradiance (gendaymtx, {n_sky} patches): {gendaymtx_total:.1f}")
# Out:
# Written: skies\cumulative_gendaymtx.rad
#
# New sky file ready: skies\cumulative_gendaymtx.rad
#
# Total cumulative sky irradiance (gendaymtx, 145 patches): 67036484.0

# %% [markdown]
# ---
# ## TODO #2: Verify `oconv` + `rtrace` with the new gendaymtx sky
#
# Build an octfile using `cumulative_gendaymtx.rad` in place of `cumulative.rad`,
# then run the same module analysis used in the original genCumSky workflow.

# %%
# Build the filelist using the new gendaymtx-derived sky (mirrors newfilelist2 above)
obj_file = [f for f in demo.getfilelist() if f.endswith('.rad') and 'objects' in f][0]
filelist_gendaymtx = [
    os.path.join('materials', 'ground.rad'),
    rad_path,
    obj_file,
]
print("Filelist for gendaymtx sky:")
for f in filelist_gendaymtx:
    print(f"  {f}")

octfile_new = demo.makeOct(filelist_gendaymtx, octname='tutorial_1_gendaymtx')
print(f"\nCreated octfile: {octfile_new}")
# Out:
# Filelist for gendaymtx sky:
#   materials\ground.rad
#   skies\cumulative_gendaymtx.rad
#   objects\test-module_C_0.20_rtr_3.00_tilt_10_20modsx7rows_origin0,0.rad
# Created tutorial_1_gendaymtx.oct
#
# Created octfile: tutorial_1_gendaymtx.oct

# %%
# Run the same module analysis with the new sky octfile
analysis_new = br.AnalysisObj(octfile_new, demo.basename + '_gendaymtx')
frontscan_new, backscan_new = analysis_new.moduleAnalysis(scene)
results_new = analysis_new.analysis(
    octfile_new, demo.basename + '_gendaymtx', frontscan_new, backscan_new)
# Out:
# Linescan in process: tutorial_1_gendaymtx_Row4_Module10_Front
# Linescan in process: tutorial_1_gendaymtx_Row4_Module10_Back
# Saved: results\irr_tutorial_1_gendaymtx_Row4_Module10.csv

# %%
print(analysis_new.Wm2Front)
print(analysis_new.Wm2Back)

elapsed_new = time.time() - start_time
print(f"Total time: {elapsed_new:.2f} seconds")
# Out:
# [1639791. 1640074. 1640381. 1640688. 1640995. 1641302. 1641608. 1641915.
#  1648228.]
# [132421.9  107823.2   83570.17  71765.74  67808.28  69852.41  77284.01
#   91507.55 110674.2 ]
# Total time: 99.34 seconds

# %% [markdown]
# ---
# ## TODO #3: Compare numerical results — `genCumSky()` vs `gendaymtx`
#
# Load the saved CSV results from both simulations and compare front/back irradiance.
# A close match (< ~5% difference) validates the pipeline replacement.
# Large differences may indicate an azimuth offset or unit scaling issue in the .cal conversion.

# %%
front_orig = analysis.Wm2Front.mean()
back_orig  = analysis.Wm2Back.mean()
front_new  = analysis_new.Wm2Front.mean()
back_new   = analysis_new.Wm2Back.mean()

res_orig = pd.DataFrame()
res_orig['Wm2Front'] = analysis.Wm2Front
res_orig['Wm2Back'] = analysis.Wm2Back

res_new = pd.DataFrame()
res_new['Wm2Front'] = analysis_new.Wm2Front
res_new['Wm2Back'] = analysis_new.Wm2Back

print("=" * 55)
print(f"{'':30s} {'genCumSky':>10s} {'gendaymtx':>10s}")
print("=" * 55)
print(f"{'Front irradiance (Wh/m²)':30s} {front_orig:10.2f} {front_new:10.2f}")
print(f"{'Back  irradiance (Wh/m²)':30s} {back_orig:10.2f}  {back_new:10.2f}")
print(f"{'Bifacial ratio':30s} {back_orig/front_orig:10.4f} {back_new/front_new:10.4f}")
print("=" * 55)
print(f"{'Front Δ (Wh/m²)':30s} {front_new - front_orig:+10.2f}")
print(f"{'Back  Δ (Wh/m²)':30s} {back_new  - back_orig:+10.2f}")
print(f"{'Front Δ (%)':30s} {100*(front_new-front_orig)/front_orig:+10.2f}%")
print(f"{'Back  Δ (%)':30s} {100*(back_new -back_orig )/back_orig:+10.2f}%")
# Out:
# =======================================================
#                                 genCumSky  gendaymtx
# =======================================================
# Front irradiance (Wh/m²)       1630843.89 1641664.67
# Back  irradiance (Wh/m²)         89496.14    90300.83
# Bifacial ratio                     0.0549     0.0550
# =======================================================
# Front Δ (Wh/m²)                 +10820.78
# Back  Δ (Wh/m²)                   +804.68
# Front Δ (%)                         +0.66%
# Back  Δ (%)                         +0.90%

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

for ax, col, label in zip(axes, ['Wm2Front', 'Wm2Back'], ['Front', 'Back']):
    ax.scatter(res_orig[col], res_new[col], alpha=0.6, s=20)
    lims = [min(res_orig[col].min(), res_new[col].min()),
            max(res_orig[col].max(), res_new[col].max())]
    ax.plot(lims, lims, 'r--', label='1:1 line')
    ax.set_xlabel('genCumSky (W/m²)')
    ax.set_ylabel('gendaymtx (W/m²)')
    ax.set_title(f'{label} irradiance — point-by-point')
    ax.legend()

plt.tight_layout()
plt.savefig('gencumsky_vs_gendaymtx_comparison.png', dpi=100)
plt.show()
print("Saved: gencumsky_vs_gendaymtx_comparison.png")
# Out:
# Saved: gencumsky_vs_gendaymtx_comparison.png

# %% [markdown]
# ## Alternate method - follow rfluxmtx and dctimestep process which apparently is the more updated workflow. Works, but has extra steps

# %%
## Continue following Example 1 for annual gencumsky simulation.
# online discussion around this: https://discourse.radiance-online.org/t/gencumulativesky-ignore-diffuse-irradiance/996/3
# rfluxmtx introduced, slide 38 onward: https://www.radiance-online.org/community/workshops/2014-london/presentations/day1/Ward_WhatIsNew.pdf
# Tutorial: https://www.radiance-online.org/learning/tutorials/matrix-based-methods

# %%
# Greg ward suggestion: 
# gendaymtx will generate a sky vector corresponding to the average W/sr/M^2 of each patch. 
# This is most easily applied in a daylight coefficient calculation, where you’ve used rfluxmtx to calculate the sky-to-point 
# coefficients and dctimestep multiply the matrix against the gendaymtx sky vector output. 
# The alternative is to convert the output to a .dat file and use it with a colordata (or brightdata) 
# primitive with tregenza.cal or similar, but this is a bit less standard. In the end, you should get similar results from 
# rfluxmtx that you would from rtrace.
# In either case, you would multiply the final result by 8760/1000 to get KWh/m^2/year, 
# assuming the -I+ option was used and your weather file contains evenly-spaced values.

# %%
# Gemini details continue: create receiver.rad file
start_time = time.time()
def make_receiver(filename):
    """
    Create a static `.rad` file to act as the receiver for `rfluxmtx`. 
    This file defines the actual geometry of the sky dome so the rays have something to hit.
    """
    with open(filename, 'w') as f:
        f.write("#@rfluxmtx h=r1 u=Y\n")
        f.write("void glow sky_glow\n0\n0\n4 1 1 1 0\n")
        f.write("sky_glow source sky\n0\n0\n4 0 0 1 180\n")
        f.write("#@rfluxmtx h=u\n")
        f.write("void glow ground_glow\n0\n0\n4 1 1 1 0\n")
        f.write("ground_glow source ground\n0\n0\n4 0 0 -1 180\n")
    return filename  

receiver = make_receiver(os.path.join('objects', 'receiver.rad'))

# %%
filelist_nosky = demo.getfilelist()
# create groundplane
with open('objects/groundplane.rad','w') as f:
    f.write('void plastic custom\n0\n0\n5 0.200 0.200 0.200 0 0\n\ncustom ring groundplane\n0\n0\n8\n0 0 -.01\n0 0 1\n0 100')
filelist_nosky = [ filelist_nosky[0], 'objects/groundplane.rad', filelist_nosky[2]]
print(filelist_nosky)
octfile_nosky = demo.makeOct(filelist_nosky, octname='tutorial_1_nosky')
# Out:
# ['materials\\ground.rad', 'objects/groundplane.rad', 'objects\\test-module_C_0.20_rtr_3.00_tilt_10_20modsx7rows_origin0,0.rad']
# Created tutorial_1_nosky.oct

# %%
# Then, run `rfluxmtx` to calculate how much of each sky patch is visible from your sensors, 
# taking into account the shading and reflections of your scene.
# cat sensors.txt | rfluxmtx -ab 4 -ad 1000 - receiver.rad -i scene.oct > daylight_coefficients.mtx

linepts = analysis._linePtsMakeDict(frontscan)
#print(linepts)
# convert linepts to scan with rtrace:
cmd = "rtrace -h -opn tutorial_1_nosky.oct"
surface_points,err = _popen(cmd,linepts.encode())
if err is not None: print(err)

# next command makes use of existing octree
cmd = "rfluxmtx -I+ -ab 5 -ad 2048 - objects/receiver.rad -i tutorial_1_nosky.oct > daylight_coefficients.mtx"
# build fresh octree. Note this recompiles the octree each time, taking extra memory if its run multiple times.
# note: If you have a large number of .rad files, you don't need to type them all out manually. use e.g.
# rfluxmtx -ab 4 -ad 1000 - receiver.rad materials/*.mat objects/*.rad
#cmd = "rfluxmtx -ab 5 -ad 2048 - objects/receiver.rad materials/ground.rad objects/test-module_C_0.20_rtr_3.00_tilt_10_20modsx7rows_origin0,0.rad > daylight_coefficients.mtx"

temp_out,err = _popen(cmd,surface_points.encode())
if err is not None:
    if err[0:5] == 'error':
        raise Exception(err[7:])
    else:
        print(err)
# Out:
# message: rtrace: warning - no light sources found

# %%
# Now use `dctimestep` to multiply the geometric matrix ($\mathbf{D}$) by the annual sky matrix ($\mathbf{S}$).
# dctimestep daylight_coefficients.mtx annual_sky.smx > final_results.dat
cmd = "dctimestep daylight_coefficients.mtx EPWs/totalirrad_results.mtx"
text_data,err = _popen(cmd,None)
if err is not None:
    if err[0:5] == 'error':
        raise Exception(err[7:])
    else:
        print(err)
# Out:
# message: fatal - unexpected EOF in header

# %%
annual_front = convert_to_annual_whm2(text_data)
print(annual_front)  #good match...
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 annual_front = convert_to_annual_whm2(text_data)
#       2 print(annual_front)  #good match...
#
# Cell In[21], line 14, in convert_to_annual_whm2(text_data)
#       9 """
#      10 Parses Radiance dctimestep output and returns a NumPy array of annual Wh/m^2.
#      11 """
#      12 annual_wh_m2 = []
# ---> 14 for line in text_data.strip().split('\n'):
#      15     parts = line.split()
#      17     # Data lines will have exactly 3 components (RGB)
#
# AttributeError: 'NoneType' object has no attribute 'strip'

# %%
linepts = analysis._linePtsMakeDict(backscan)
#print(linepts)
# convert linepts to scan with rtrace:
cmd = "rtrace -h -opn tutorial_1_nosky.oct"
surface_points,err = _popen(cmd,linepts.encode())
if err is not None: print(err)

# next command makes use of existing octree
cmd = "rfluxmtx -I+ -ab 5 -ad 2048 - objects/receiver.rad -i tutorial_1_nosky.oct > daylight_coefficients.mtx"
# build fresh octree. Note this recompiles the octree each time, taking extra memory if its run multiple times.
# note: If you have a large number of .rad files, you don't need to type them all out manually. use e.g.
# rfluxmtx -ab 4 -ad 1000 - receiver.rad materials/*.mat objects/*.rad
#cmd = "rfluxmtx -ab 5 -ad 2048 - objects/receiver.rad materials/ground.rad objects/test-module_C_0.20_rtr_3.00_tilt_10_20modsx7rows_origin0,0.rad > daylight_coefficients.mtx"

temp_out,err = _popen(cmd,surface_points.encode())
if err is not None: print(err)

cmd = "dctimestep daylight_coefficients.mtx EPWs/totalirrad_results.mtx"
text_data,err = _popen(cmd,None)
if err is not None: print(err)

annual_back = convert_to_annual_whm2(text_data)
print(annual_back)  #good match...

# %%
elapsed_rfluxmtx = time.time() - start_time
print(f"Total time: {elapsed_rfluxmtx:.2f} seconds")

# %%
res_annual = pd.DataFrame()
res_annual['Wm2Front'] = annual_front
res_annual['Wm2Back'] = annual_back

print("=" * 75)
print(f"{'':30s} {'genCumSky':>10s} {'gendaymtx':>10s} {'rfluxmtx':>10s}")
print("=" * 75)
print(f"{'Front irradiance (Wh/m²)':30s} {front_orig:10.2f} {front_new:10.2f} {np.mean(annual_front):10.2f}")
print(f"{'Back  irradiance (Wh/m²)':30s} {back_orig:10.2f}  {back_new:10.2f} {np.mean(annual_back):10.2f}")
print(f"{'Bifacial ratio':30s} {back_orig/front_orig:10.4f} {back_new/front_new:10.4f} {np.mean(annual_back)/np.mean(annual_front):10.4f}")
print("=" * 75)
print(f"{'Front Δ (Wh/m²)':30s} {front_new - front_orig:+10.2f}")
print(f"{'Back  Δ (Wh/m²)':30s} {back_new  - back_orig:+10.2f}")
print(f"{'Front Δ (%)':30s} {100*(front_new-front_orig)/front_orig:+10.2f}%  {100*(np.mean(annual_front)-front_orig)/front_orig:+10.2f}%")
print(f"{'Back  Δ (%)':30s} {100*(back_new -back_orig )/back_orig:+10.2f}%  {100*(np.mean(annual_back) -back_orig )/back_orig:+10.2f}%")

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

for ax, col, label in zip(axes, ['Wm2Front', 'Wm2Back'], ['Front', 'Back']):
    ax.scatter(res_orig[col], res_annual[col], alpha=0.6, s=20)
    lims = [min(res_orig[col].min(), res_annual[col].min()),
            max(res_orig[col].max(), res_annual[col].max())]
    ax.plot(lims, lims, 'r--', label='1:1 line')
    ax.set_xlabel('genCumSky (W/m²)')
    ax.set_ylabel('rfluxmtx (W/m²)')
    ax.set_title(f'{label} irradiance — point-by-point')
    ax.legend()

plt.tight_layout()
plt.savefig('gencumsky_vs_rfluxmtx_comparison.png', dpi=100)
plt.show()
print("Saved: gencumsky_vs_rfluxmtx_comparison.png")

# %% [markdown]
# ## Now that the code has been updated in the 184_549_gendaymtx branch, compare runs with 'use_mtx' = True and False.

# %%
import bifacial_radiance as br
import os
import pandas as pd
import numpy as np

# %%
# Fixed-tilt gencumsky, full year
name = "fixed_gencumsky"
demo = br.RadianceObj(name,os.getcwd())  # Create a RadianceObj 'object'
demo.setGround(0.62) 
epwfile = demo.getEPW(lat = 37.5, lon = -77.6)  # This location corresponds to Richmond, VA.
metdata = demo.readWeatherFile(epwfile)
demo.genCumSky(use_mtx=False)  # 1p, June 17th
# create a scene using panels in landscape at 10 deg tilt, 1.5m pitch. 0.2 m ground clearance
sceneDict = {'tilt':10,'pitch':1.5,'clearance_height':0.2, 'nMods':10, 'nRows':3}  
demo.makeModule(name='test',y=0.95,x=1.59, xgap=0)
scene = demo.makeScene('test',sceneDict) 
octfile = demo.makeOct(demo.getfilelist())  # makeOct combines all of the ground, sky and object files into a .oct file.
analysis = br.AnalysisObj(octfile, demo.name)  # return an analysis object including the scan dimensions for back irradiance
(frontscan,backscan) = analysis.moduleAnalysis(scene)
results_fixed_gencumsky = analysis.analysis(octfile, demo.name, frontscan, backscan) 
demo1 = demo
# Out:
# path = C:\Users\cdeline\Documents\Python Scripts\Bifacial_Radiance\docs\development
# Making path: images
# Making path: objects
# Making path: results
# Making path: skies
# Making path: EPWs
# Making path: materials
# Loading albedo, 1 value(s), 0.620 avg
# 1 nonzero albedo values.
# Getting weather file: USA_VA_Richmond.724010_TMY2.epw
#  ... OK!
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos
# Loaded  EPWs\metdata_temp.csv
# message: Error!  Solar altitude is -7 < -6 degrees and Idh = 13 > 10 W/m^2 on day 76 !Ibn is 0.  Attempting to continue!
# Error!  Solar altitude is -7 < -6 degrees and Idh = 11 > 10 W/m^2 on day 78 !Ibn is 0.  Attempting to continue!
# Error!  Solar altitude is -6 < -6 degrees and Idh = 14 > 10 W/m^2 on day 81 !Ibn is 0.  Attempting to continue!
# There were 4537 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
#
# Module Name: test
# Module test updated in module.json
# Created fixed_gencumsky.oct
# Linescan in process: fixed_gencumsky_Row2_Module5_Front
# Linescan in process: fixed_gencumsky_Row2_Module5_Back
# Saved: results\irr_fixed_gencumsky_Row2_Module5.csv

# %%
print(f'Gencumsky front mean: {results_fixed_gencumsky[0]['Wm2'].mean():0.2f}')
print(f'Gencumsky rear mean: {results_fixed_gencumsky[1]['Wm2'].mean():0.2f}')
# Out:
# Gencumsky front mean: 1617400.56
# Gencumsky rear mean: 215038.19

# %%
# Fixed-tilt gendaymtx, full year
name = "fixed_gendaymtx"
demo = br.RadianceObj(name,os.getcwd())  # Create a RadianceObj 'object'
demo.setGround(0.62) 
metdata = demo.readWeatherFile(epwfile)
demo.genCumSky(use_mtx=True)  #
# create a scene using panels in landscape at 10 deg tilt, 1.5m pitch. 0.2 m ground clearance
sceneDict = {'tilt':10,'pitch':1.5,'clearance_height':0.2, 'nMods':10, 'nRows':3}  
demo.makeModule(name='test',y=0.95,x=1.59, xgap=0)
scene = demo.makeScene('test',sceneDict) 
octfile = demo.makeOct(demo.getfilelist())  # makeOct combines all of the ground, sky and object files into a .oct file.
analysis = br.AnalysisObj(octfile, demo.name)  # return an analysis object including the scan dimensions for back irradiance
(frontscan,backscan) = analysis.moduleAnalysis(scene)
results_fixed_gendaymtx = analysis.analysis(octfile, demo.name, frontscan, backscan)
# Out:
# path = C:\Users\cdeline\Documents\Python Scripts\Bifacial_Radiance\docs\development
# Loading albedo, 1 value(s), 0.620 avg
# 1 nonzero albedo values.
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos
# Saving file EPWs\temp.wea
# message: gendaymtx: warning - unusually bright at 17.0 on 1-2
# gendaymtx: warning - unusually bright at 17.0 on 1-3
# gendaymtx: warning - unusually bright at 17.0 on 1-4
# gendaymtx: warning - unusually bright at 17.0 on 1-5
# gendaymtx: warning - unusually bright at 17.0 on 1-6
# gendaymtx: warning - unusually bright at 17.0 on 1-8
# gendaymtx: warning - unusually bright at 17.0 on 1-11
# gendaymtx: warning - unusually bright at 17.0 on 1-12
# gendaymtx: warning - unusually bright at 17.0 on 1-14
# gendaymtx: warning - unusually bright at 18.0 on 1-14
# gendaymtx: warning - unusually bright at 17.0 on 1-17
# gendaymtx: warning - unusually bright at 18.0 on 1-17
# gendaymtx: warning - unusually bright at 17.0 on 1-18
# gendaymtx: warning - unusually bright at 17.0 on 1-19
# gendaymtx: warning - unusually bright at 18.0 on 1-19
# gendaymtx: warning - unusually bright at 17.0 on 1-20
# gendaymtx: warning - unusually bright at 17.0 on 1-21
# gendaymtx: warning - unusually bright at 17.0 on 1-22
# gendaymtx: warning - unusually bright at 18.0 on 1-22
# gendaymtx: warning - unusually bright at 18.0 on 1-27
# gendaymtx: warning - unusually bright at 18.0 on 1-28
# gendaymtx: warning - unusually bright at 18.0 on 1-31
# gendaymtx: warning - unusually bright at 18.0 on 2-1
# gendaymtx: warning - unusually bright at 18.0 on 2-2
# gendaymtx: warning - unusually bright at 18.0 on 2-5
# gendaymtx: warning - unusually bright at 18.0 on 2-6
# gendaymtx: warning - unusually bright at 18.0 on 2-9
# gendaymtx: warning - unusually bright at 18.0 on 2-10
# gendaymtx: warning - unusually bright at 18.0 on 2-11
# gendaymtx: warning - unusually bright at 18.0 on 2-12
# gendaymtx: warning - unusually bright at 18.0 on 2-14
# gendaymtx: warning - unusually bright at 18.0 on 2-15
# gendaymtx: warning - unusually bright at 18.0 on 2-16
# gendaymtx: warning - unusually bright at 18.0 on 2-17
# gendaymtx: warning - unusually bright at 18.0 on 2-18
# gendaymtx: warning - unusually bright at 18.0 on 2-20
# gendaymtx: warning - unusually bright at 18.0 on 2-23
# gendaymtx: warning - unusually bright at 18.0 on 2-24
# gendaymtx: warning - unusually bright at 18.0 on 2-25
# gendaymtx: warning - unusually bright at 18.0 on 2-27
# gendaymtx: warning - unusually bright at 18.0 on 2-28
# gendaymtx: warning - unusually bright at 18.0 on 3-1
# gendaymtx: warning - unusually bright at 18.0 on 3-2
# gendaymtx: warning - unusually bright at 18.0 on 3-4
# gendaymtx: warning - unusually bright at 18.0 on 3-5
# gendaymtx: warning - unusually bright at 18.0 on 3-6
# gendaymtx: warning - unusually bright at 18.0 on 3-7
# gendaymtx: warning - unusually bright at 18.0 on 3-8
# gendaymtx: warning - unusually bright at 19.0 on 3-8
# gendaymtx: warning - unusually bright at 18.0 on 3-9
# gendaymtx: warning - unusually bright at 18.0 on 3-10
# gendaymtx: warning - unusually bright at 18.0 on 3-11
# gendaymtx: warning - unusually bright at 18.0 on 3-12
# gendaymtx: warning - unusually bright at 18.0 on 3-13
# gendaymtx: warning - unusually bright at 18.0 on 3-15
# gendaymtx: warning - unusually bright at 18.0 on 3-18
# gendaymtx: warning - unusually bright at 19.0 on 3-18
# gendaymtx: warning - unusually bright at 18.0 on 3-19
# gendaymtx: warning - unusually bright at 19.0 on 3-19
# gendaymtx: warning - unusually bright at 18.0 on 3-21
# gendaymtx: warning - unusually bright at 18.0 on 3-22
# gendaymtx: warning - unusually bright at 19.0 on 3-22
# gendaymtx: warning - unusually bright at 19.0 on 3-26
# gendaymtx: warning - unusually bright at 19.0 on 3-27
# gendaymtx: warning - unusually bright at 19.0 on 3-30
# gendaymtx: warning - unusually bright at 19.0 on 4-2
# gendaymtx: warning - unusually bright at 19.0 on 4-4
# gendaymtx: warning - unusually bright at 19.0 on 4-7
# gendaymtx: warning - unusually bright at 19.0 on 4-11
# gendaymtx: warning - unusually bright at 19.0 on 4-12
# gendaymtx: warning - unusually bright at 19.0 on 4-15
# gendaymtx: warning - unusually bright at 19.0 on 4-18
# gendaymtx: warning - unusually bright at 19.0 on 4-19
# gendaymtx: warning - unusually bright at 19.0 on 4-20
# gendaymtx: warning - unusually bright at 19.0 on 4-22
# gendaymtx: warning - unusually bright at 19.0 on 4-23
# gendaymtx: warning - unusually bright at 19.0 on 4-24
# gendaymtx: warning - unusually bright at 19.0 on 4-25
# gendaymtx: warning - unusually bright at 19.0 on 4-27
# gendaymtx: warning - unusually bright at 19.0 on 4-29
# gendaymtx: warning - unusually bright at 19.0 on 5-3
# gendaymtx: warning - unusually bright at 19.0 on 5-4
# gendaymtx: warning - unusually bright at 19.0 on 5-5
# gendaymtx: warning - unusually bright at 19.0 on 5-6
# gendaymtx: warning - unusually bright at 19.0 on 5-7
# gendaymtx: warning - unusually bright at 19.0 on 5-10
# gendaymtx: warning - unusually bright at 19.0 on 5-11
# gendaymtx: warning - unusually bright at 19.0 on 5-15
# gendaymtx: warning - unusually bright at 19.0 on 5-16
# gendaymtx: warning - unusually bright at 19.0 on 5-17
# gendaymtx: warning - unusually bright at 19.0 on 5-19
# gendaymtx: warning - unusually bright at 19.0 on 5-20
# gendaymtx: warning - unusually bright at 19.0 on 5-21
# gendaymtx: warning - unusually bright at 19.0 on 5-22
# gendaymtx: warning - unusually bright at 19.0 on 5-23
# gendaymtx: warning - unusually bright at 19.0 on 5-26
# gendaymtx: warning - unusually bright at 19.0 on 5-28
# gendaymtx: warning - unusually bright at 20.0 on 6-21
# gendaymtx: warning - unusually bright at 20.0 on 6-25
# gendaymtx: warning - unusually bright at 20.0 on 6-26
# gendaymtx: warning - unusually bright at 20.0 on 7-5
# gendaymtx: warning - unusually bright at 20.0 on 7-6
# gendaymtx: warning - unusually bright at 20.0 on 7-7
# gendaymtx: warning - unusually bright at 20.0 on 7-8
# gendaymtx: warning - unusually bright at 20.0 on 7-12
# gendaymtx: warning - unusually bright at 20.0 on 7-13
# gendaymtx: warning - unusually bright at 20.0 on 7-25
# gendaymtx: warning - unusually bright at 19.0 on 7-28
# gendaymtx: warning - unusually bright at 19.0 on 7-29
# gendaymtx: warning - unusually bright at 19.0 on 7-30
# gendaymtx: warning - unusually bright at 19.0 on 8-1
# gendaymtx: warning - unusually bright at 19.0 on 8-2
# gendaymtx: warning - unusually bright at 19.0 on 8-3
# gendaymtx: warning - unusually bright at 19.0 on 8-4
# gendaymtx: warning - unusually bright at 19.0 on 8-5
# gendaymtx: warning - unusually bright at 19.0 on 8-7
# gendaymtx: warning - unusually bright at 19.0 on 8-8
# gendaymtx: warning - unusually bright at 19.0 on 8-9
# gendaymtx: warning - unusually bright at 19.0 on 8-15
# gendaymtx: warning - unusually bright at 19.0 on 8-22
# gendaymtx: warning - unusually bright at 19.0 on 8-24
# gendaymtx: warning - unusually bright at 19.0 on 8-25
# gendaymtx: warning - unusually bright at 19.0 on 8-26
# gendaymtx: warning - unusually bright at 19.0 on 8-28
# gendaymtx: warning - unusually bright at 19.0 on 8-30
# gendaymtx: warning - unusually bright at 19.0 on 9-4
# gendaymtx: warning - unusually bright at 19.0 on 9-7
# gendaymtx: warning - unusually bright at 19.0 on 9-8
# gendaymtx: warning - unusually bright at 18.0 on 9-13
# gendaymtx: warning - unusually bright at 18.0 on 9-14
# gendaymtx: warning - unusually bright at 18.0 on 9-15
# gendaymtx: warning - unusually bright at 18.0 on 9-17
# gendaymtx: warning - unusually bright at 18.0 on 9-18
# gendaymtx: warning - unusually bright at 18.0 on 9-19
# gendaymtx: warning - unusually bright at 18.0 on 9-20
# gendaymtx: warning - unusually bright at 18.0 on 9-21
# gendaymtx: warning - unusually bright at 18.0 on 9-22
# gendaymtx: warning - unusually bright at 18.0 on 9-23
# gendaymtx: warning - unusually bright at 18.0 on 9-25
# gendaymtx: warning - unusually bright at 18.0 on 9-27
# gendaymtx: warning - unusually bright at 18.0 on 9-29
# gendaymtx: warning - unusually bright at 18.0 on 9-30
# gendaymtx: warning - unusually bright at 18.0 on 10-1
# gendaymtx: warning - unusually bright at 18.0 on 10-3
# gendaymtx: warning - unusually bright at 18.0 on 10-4
# gendaymtx: warning - unusually bright at 18.0 on 10-9
# gendaymtx: warning - unusually bright at 18.0 on 10-10
# gendaymtx: warning - unusually bright at 18.0 on 10-12
# gendaymtx: warning - unusually bright at 18.0 on 10-16
# gendaymtx: warning - unusually bright at 18.0 on 10-17
# gendaymtx: warning - unusually bright at 18.0 on 10-19
# gendaymtx: warning - unusually bright at 17.0 on 10-21
# gendaymtx: warning - unusually bright at 18.0 on 10-21
# gendaymtx: warning - unusually bright at 17.0 on 10-22
# gendaymtx: warning - unusually bright at 18.0 on 10-22
# gendaymtx: warning - unusually bright at 17.0 on 10-23
# gendaymtx: warning - unusually bright at 17.0 on 10-24
# gendaymtx: warning - unusually bright at 18.0 on 10-24
# gendaymtx: warning - unusually bright at 17.0 on 10-28
# gendaymtx: warning - unusually bright at 17.0 on 10-29
# gendaymtx: warning - unusually bright at 17.0 on 10-30
# gendaymtx: warning - unusually bright at 18.0 on 10-30
# gendaymtx: warning - unusually bright at 17.0 on 10-31
# gendaymtx: warning - unusually bright at 17.0 on 11-4
# gendaymtx: warning - unusually bright at 17.0 on 11-5
# gendaymtx: warning - unusually bright at 17.0 on 11-9
# gendaymtx: warning - unusually bright at 17.0 on 11-10
# gendaymtx: warning - unusually bright at 17.0 on 11-11
# gendaymtx: warning - unusually bright at 17.0 on 11-12
# gendaymtx: warning - unusually bright at 17.0 on 11-13
# gendaymtx: warning - unusually bright at 17.0 on 11-15
# gendaymtx: warning - unusually bright at 17.0 on 11-16
# gendaymtx: warning - unusually bright at 17.0 on 11-17
# gendaymtx: warning - unusually bright at 17.0 on 11-18
# gendaymtx: warning - unusually bright at 17.0 on 11-19
# gendaymtx: warning - unusually bright at 17.0 on 11-20
# gendaymtx: warning - unusually bright at 17.0 on 11-21
# gendaymtx: warning - unusually bright at 17.0 on 11-23
# gendaymtx: warning - unusually bright at 17.0 on 11-24
# gendaymtx: warning - unusually bright at 17.0 on 11-25
# gendaymtx: warning - unusually bright at 17.0 on 11-26
# gendaymtx: warning - unusually bright at 17.0 on 11-29
# gendaymtx: warning - unusually bright at 17.0 on 11-30
# gendaymtx: warning - unusually bright at 17.0 on 12-2
# gendaymtx: warning - unusually bright at 17.0 on 12-4
# gendaymtx: warning - unusually bright at 17.0 on 12-5
# gendaymtx: warning - unusually bright at 17.0 on 12-6
# gendaymtx: warning - unusually bright at 17.0 on 12-7
# gendaymtx: warning - unusually bright at 17.0 on 12-8
# gendaymtx: warning - unusually bright at 17.0 on 12-9
# gendaymtx: warning - unusually bright at 17.0 on 12-10
# gendaymtx: warning - unusually bright at 17.0 on 12-13
# gendaymtx: warning - unusually bright at 17.0 on 12-14
# gendaymtx: warning - unusually bright at 17.0 on 12-15
# gendaymtx: warning - unusually bright at 17.0 on 12-17
# gendaymtx: warning - unusually bright at 17.0 on 12-18
# gendaymtx: warning - unusually bright at 17.0 on 12-19
# gendaymtx: warning - unusually bright at 17.0 on 12-20
# gendaymtx: warning - unusually bright at 17.0 on 12-24
# gendaymtx: warning - unusually bright at 17.0 on 12-25
# gendaymtx: warning - unusually bright at 17.0 on 12-26
# gendaymtx: warning - unusually bright at 17.0 on 12-27
# gendaymtx: warning - unusually bright at 17.0 on 12-28
# gendaymtx: warning - unusually bright at 17.0 on 12-30
# Written: cumulative.cal  (145 sky patches encoded, M=1)
#
# Module Name: test
# Module test updated in module.json
# Pre-existing .rad file objects\test.rad will be overwritten
#
# Created fixed_gendaymtx.oct
# Linescan in process: fixed_gendaymtx_Row2_Module5_Front
# Linescan in process: fixed_gendaymtx_Row2_Module5_Back
# Saved: results\irr_fixed_gendaymtx_Row2_Module5.csv

# %%
print(f'Gendaymtx / Gencumsky front mean: {results_fixed_gendaymtx[0]['Wm2'].mean() / results_fixed_gencumsky[0]['Wm2'].mean():0.3f}')
print(f'Gendaymtx / Gencumsky rear mean: {results_fixed_gendaymtx[1]['Wm2'].mean()/ results_fixed_gencumsky[1]['Wm2'].mean():0.3f}')
# Out:
# Gendaymtx / Gencumsky front mean: 1.007
# Gendaymtx / Gencumsky rear mean: 0.995

# %%
# 1-axis tracked, gencumsky, full year
name = "1axis_gencumSky"
use_mtx=False
gcr = 0.35   # ground cover ratio,  = module_height / pitch
albedo = 0.6     # ground albedo
hub_height = 2   # tracker height at 0 tilt in meters (hub height)

demo = br.RadianceObj(name)  # Create a RadianceObj 'object'
demo.setGround(albedo) # input albedo number or material name like 'concrete'.  To see options, run this without any input.
metdata = demo.readWeatherFile(epwfile)
module=demo.makeModule(name='test-module',x=0.984,y=1.95, numpanels = 2, ygap = 0.1)
pitch= np.round(module.sceney / gcr,3)
trackerdict = demo.set1axis(cumulativesky=True, gcr=gcr, use_mtx=use_mtx)
demo.genCumSky1axis(use_mtx=use_mtx)
sceneDict = {'gcr': gcr,'hub_height':hub_height, 'clearance_height':hub_height, 'nMods':10, 'nRows':3}  
trackerdict = demo.makeScene1axis(sceneDict=sceneDict, module='test-module')

trackerdict = demo.makeOct1axis() # just run this for one timestep: -5 degrees
trackerdict = demo.analysis1axis( modWanted=7, rowWanted=3, sensorsy=2)
# Out:
# path = C:\Users\cdeline\Documents\Python Scripts\Bifacial_Radiance\docs\development
# Loading albedo, 1 value(s), 0.600 avg
# 1 nonzero albedo values.
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos
#
# Module Name: test-module
# Module test-module updated in module.json
# Saving file EPWs\1axis_-45.0.csv, # points: 767
# Saving file EPWs\1axis_-40.0.csv, # points: 182
# Saving file EPWs\1axis_-35.0.csv, # points: 146
# Saving file EPWs\1axis_-30.0.csv, # points: 154
# Saving file EPWs\1axis_-25.0.csv, # points: 201
# Saving file EPWs\1axis_-20.0.csv, # points: 112
# Saving file EPWs\1axis_-15.0.csv, # points: 129
# Saving file EPWs\1axis_-10.0.csv, # points: 360
# Saving file EPWs\1axis_-5.0.csv, # points: 159
# Saving file EPWs\1axis_0.0.csv, # points: 61
# Saving file EPWs\1axis_5.0.csv, # points: 252
# Saving file EPWs\1axis_10.0.csv, # points: 98
# Saving file EPWs\1axis_15.0.csv, # points: 128
# Saving file EPWs\1axis_20.0.csv, # points: 242
# Saving file EPWs\1axis_25.0.csv, # points: 134
# Saving file EPWs\1axis_30.0.csv, # points: 120
# Saving file EPWs\1axis_35.0.csv, # points: 179
# Saving file EPWs\1axis_40.0.csv, # points: 151
# Saving file EPWs\1axis_45.0.csv, # points: 792
# message: There were 761 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_-45.0.rad
# message: There were 179 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_-40.0.rad
# message: There were 146 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_-35.0.rad
# message: There were 154 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_-30.0.rad
# message: There were 199 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_-25.0.rad
# message: There were 110 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_-20.0.rad
# message: There were 128 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_-15.0.rad
# message: There were 352 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_-10.0.rad
# message: There were 143 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_-5.0.rad
# message: There were 53 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_0.0.rad
# message: There were 249 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_5.0.rad
# message: There were 95 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_10.0.rad
# message: There were 121 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_15.0.rad
# message: There were 240 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_20.0.rad
# message: There were 132 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_25.0.rad
# message: There were 120 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_30.0.rad
# message: There were 174 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_35.0.rad
# message: There were 151 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_40.0.rad
# message: There were 784 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies\1axis_45.0.rad
# sceneDict Warning: 'hub_height' and 'clearance_height' are being passed. Using hub_height and removing clearance_height
#
# Making .rad files for cumulativesky 1-axis workflow
# 19 Radfiles created in /objects/
#
# Making 19 octfiles in root directory.
# Created 1axis_-45.0.oct
# Created 1axis_-40.0.oct
# Created 1axis_-35.0.oct
# Created 1axis_-30.0.oct
# Created 1axis_-25.0.oct
# Created 1axis_-20.0.oct
# Created 1axis_-15.0.oct
# Created 1axis_-10.0.oct
# Created 1axis_-5.0.oct
# Created 1axis_0.0.oct
# Created 1axis_5.0.oct
# Created 1axis_10.0.oct
# Created 1axis_15.0.oct
# Created 1axis_20.0.oct
# Created 1axis_25.0.oct
# Created 1axis_30.0.oct
# Created 1axis_35.0.oct
# Created 1axis_40.0.oct
# Created 1axis_45.0.oct
# Linescan in process: 1axis_-45.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-45.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-45.0_Scene0_Row3_Module7.csv
# Index: -45.0. Wm2Front: 334798.5. Wm2Back: 63580.125
# Linescan in process: 1axis_-40.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-40.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-40.0_Scene0_Row3_Module7.csv
# Index: -40.0. Wm2Front: 87058.85. Wm2Back: 18521.09
# Linescan in process: 1axis_-35.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-35.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-35.0_Scene0_Row3_Module7.csv
# Index: -35.0. Wm2Front: 65579.075. Wm2Back: 14528.6
# Linescan in process: 1axis_-30.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-30.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-30.0_Scene0_Row3_Module7.csv
# Index: -30.0. Wm2Front: 60820.520000000004. Wm2Back: 14519.880000000001
# Linescan in process: 1axis_-25.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-25.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-25.0_Scene0_Row3_Module7.csv
# Index: -25.0. Wm2Front: 105040.05000000002. Wm2Back: 25474.45
# Linescan in process: 1axis_-20.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-20.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-20.0_Scene0_Row3_Module7.csv
# Index: -20.0. Wm2Front: 36724.994999999995. Wm2Back: 9418.605500000001
# Linescan in process: 1axis_-15.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-15.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-15.0_Scene0_Row3_Module7.csv
# Index: -15.0. Wm2Front: 30611.019999999997. Wm2Back: 8017.057500000001
# Linescan in process: 1axis_-10.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-10.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-10.0_Scene0_Row3_Module7.csv
# Index: -10.0. Wm2Front: 151637.65. Wm2Back: 40161.06
# Linescan in process: 1axis_-5.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-5.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-5.0_Scene0_Row3_Module7.csv
# Index: -5.0. Wm2Front: 3428.1544999999996. Wm2Back: 1035.711
# Linescan in process: 1axis_0.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_0.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_0.0_Scene0_Row3_Module7.csv
# Index: 0.0. Wm2Front: 1255.2265. Wm2Back: 361.6879
# Linescan in process: 1axis_5.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_5.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_5.0_Scene0_Row3_Module7.csv
# Index: 5.0. Wm2Front: 153743.0. Wm2Back: 39423.83
# Linescan in process: 1axis_10.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_10.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_10.0_Scene0_Row3_Module7.csv
# Index: 10.0. Wm2Front: 27607.935000000005. Wm2Back: 7201.289000000001
# Linescan in process: 1axis_15.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_15.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_15.0_Scene0_Row3_Module7.csv
# Index: 15.0. Wm2Front: 33351.270000000004. Wm2Back: 7991.799500000001
# Linescan in process: 1axis_20.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_20.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_20.0_Scene0_Row3_Module7.csv
# Index: 20.0. Wm2Front: 128056.0. Wm2Back: 28808.91
# Linescan in process: 1axis_25.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_25.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_25.0_Scene0_Row3_Module7.csv
# Index: 25.0. Wm2Front: 59903.97499999999. Wm2Back: 12195.86
# Linescan in process: 1axis_30.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_30.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_30.0_Scene0_Row3_Module7.csv
# Index: 30.0. Wm2Front: 66055.8. Wm2Back: 12789.64
# Linescan in process: 1axis_35.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_35.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_35.0_Scene0_Row3_Module7.csv
# Index: 35.0. Wm2Front: 98748.905. Wm2Back: 17828.515
# Linescan in process: 1axis_40.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_40.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_40.0_Scene0_Row3_Module7.csv
# Index: 40.0. Wm2Front: 77965.6. Wm2Back: 13334.505000000001
# Linescan in process: 1axis_45.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_45.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_45.0_Scene0_Row3_Module7.csv
# Index: 45.0. Wm2Front: 432556.1. Wm2Back: 63383.58500000001

# %%
print(f'Gencumsky front mean 30 deg: {trackerdict[30]['AnalysisObj'][0].Wm2Front.mean():0.2f}')
print(f'Gencumsky front mean -45 deg: {trackerdict[-45]['AnalysisObj'][0].Wm2Front.mean():0.2f}')
print(f'Gencumsky back mean 30 deg: {trackerdict[30]['AnalysisObj'][0].Wm2Back.mean():0.2f}')
print(f'Gencumsky back mean -45 deg: {trackerdict[-45]['AnalysisObj'][0].Wm2Back.mean():0.2f}')
# Out:
# Gencumsky front mean 30 deg: 66055.80
# Gencumsky front mean -45 deg: 334798.50
# Gencumsky back mean 30 deg: 12789.64
# Gencumsky back mean -45 deg: 63580.12

# %%
# 1-axis tracked, gencumsky, full year
name = "1axis_gencumSky"
use_mtx=True
gcr = 0.35   # ground cover ratio,  = module_height / pitch
albedo = 0.6     # ground albedo
hub_height = 2   # tracker height at 0 tilt in meters (hub height)

demo = br.RadianceObj(name)  # Create a RadianceObj 'object'
demo.setGround(albedo) # input albedo number or material name like 'concrete'.  To see options, run this without any input.
metdata = demo.readWeatherFile(epwfile)
module=demo.makeModule(name='test-module',x=0.984,y=1.95, numpanels = 2, ygap = 0.1)
pitch= np.round(module.sceney / gcr,3)
trackerdictMTX = demo.set1axis(cumulativesky=True, gcr=gcr, use_mtx=use_mtx)
demo.genCumSky1axis(use_mtx=use_mtx)
sceneDict = {'gcr': gcr,'hub_height':hub_height, 'clearance_height':hub_height, 'nMods':10, 'nRows':3}  
trackerdictMTX = demo.makeScene1axis(sceneDict=sceneDict, module='test-module')

trackerdictMTX = demo.makeOct1axis() # just run this for one timestep: -5 degrees
trackerdictMTX = demo.analysis1axis( modWanted=7, rowWanted=3, sensorsy=2)
# Out:
# path = C:\Users\cdeline\Documents\Python Scripts\Bifacial_Radiance\docs\development
# Loading albedo, 1 value(s), 0.600 avg
# 1 nonzero albedo values.
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos
#
# Module Name: test-module
# Module test-module updated in module.json
# Pre-existing .rad file objects\test-module.rad will be overwritten
#
# Saving file EPWs\1axis_-45.0.wea, # points: 767
# Saving file EPWs\1axis_-40.0.wea, # points: 182
# Saving file EPWs\1axis_-35.0.wea, # points: 146
# Saving file EPWs\1axis_-30.0.wea, # points: 154
# Saving file EPWs\1axis_-25.0.wea, # points: 201
# Saving file EPWs\1axis_-20.0.wea, # points: 112
# Saving file EPWs\1axis_-15.0.wea, # points: 129
# Saving file EPWs\1axis_-10.0.wea, # points: 360
# Saving file EPWs\1axis_-5.0.wea, # points: 159
# Saving file EPWs\1axis_0.0.wea, # points: 61
# Saving file EPWs\1axis_5.0.wea, # points: 252
# Saving file EPWs\1axis_10.0.wea, # points: 98
# Saving file EPWs\1axis_15.0.wea, # points: 128
# Saving file EPWs\1axis_20.0.wea, # points: 242
# Saving file EPWs\1axis_25.0.wea, # points: 134
# Saving file EPWs\1axis_30.0.wea, # points: 120
# Saving file EPWs\1axis_35.0.wea, # points: 179
# Saving file EPWs\1axis_40.0.wea, # points: 151
# Saving file EPWs\1axis_45.0.wea, # points: 792
# Written: 1axis_-45.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_-45.0.rad
# Written: 1axis_-40.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_-40.0.rad
# Written: 1axis_-35.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_-35.0.rad
# Written: 1axis_-30.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_-30.0.rad
# Written: 1axis_-25.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_-25.0.rad
# Written: 1axis_-20.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_-20.0.rad
# Written: 1axis_-15.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_-15.0.rad
# Written: 1axis_-10.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_-10.0.rad
# Written: 1axis_-5.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_-5.0.rad
# Written: 1axis_0.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_0.0.rad
# Written: 1axis_5.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_5.0.rad
# Written: 1axis_10.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_10.0.rad
# Written: 1axis_15.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_15.0.rad
# Written: 1axis_20.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_20.0.rad
# Written: 1axis_25.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_25.0.rad
# Written: 1axis_30.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_30.0.rad
# Written: 1axis_35.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_35.0.rad
# Written: 1axis_40.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_40.0.rad
# Written: 1axis_45.0.cal  (145 sky patches encoded, M=1)
# Created skyfile skies\1axis_45.0.rad
# sceneDict Warning: 'hub_height' and 'clearance_height' are being passed. Using hub_height and removing clearance_height
#
# Making .rad files for cumulativesky 1-axis workflow
# 19 Radfiles created in /objects/
#
# Making 19 octfiles in root directory.
# Created 1axis_-45.0.oct
# Created 1axis_-40.0.oct
# Created 1axis_-35.0.oct
# Created 1axis_-30.0.oct
# Created 1axis_-25.0.oct
# Created 1axis_-20.0.oct
# Created 1axis_-15.0.oct
# Created 1axis_-10.0.oct
# Created 1axis_-5.0.oct
# Created 1axis_0.0.oct
# Created 1axis_5.0.oct
# Created 1axis_10.0.oct
# Created 1axis_15.0.oct
# Created 1axis_20.0.oct
# Created 1axis_25.0.oct
# Created 1axis_30.0.oct
# Created 1axis_35.0.oct
# Created 1axis_40.0.oct
# Created 1axis_45.0.oct
# Linescan in process: 1axis_-45.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-45.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-45.0_Scene0_Row3_Module7.csv
# Index: -45.0. Wm2Front: 360040.25. Wm2Back: 67495.16
# Linescan in process: 1axis_-40.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-40.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-40.0_Scene0_Row3_Module7.csv
# Index: -40.0. Wm2Front: 93499.975. Wm2Back: 19560.745000000003
# Linescan in process: 1axis_-35.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-35.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-35.0_Scene0_Row3_Module7.csv
# Index: -35.0. Wm2Front: 69524.1. Wm2Back: 15298.94
# Linescan in process: 1axis_-30.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-30.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-30.0_Scene0_Row3_Module7.csv
# Index: -30.0. Wm2Front: 63991.240000000005. Wm2Back: 14943.404999999999
# Linescan in process: 1axis_-25.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-25.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-25.0_Scene0_Row3_Module7.csv
# Index: -25.0. Wm2Front: 109779.1. Wm2Back: 26482.645
# Linescan in process: 1axis_-20.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-20.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-20.0_Scene0_Row3_Module7.csv
# Index: -20.0. Wm2Front: 37624.244999999995. Wm2Back: 9890.426
# Linescan in process: 1axis_-15.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-15.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-15.0_Scene0_Row3_Module7.csv
# Index: -15.0. Wm2Front: 32024.905. Wm2Back: 8675.9535
# Linescan in process: 1axis_-10.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-10.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-10.0_Scene0_Row3_Module7.csv
# Index: -10.0. Wm2Front: 156755.35. Wm2Back: 41446.585
# Linescan in process: 1axis_-5.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_-5.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_-5.0_Scene0_Row3_Module7.csv
# Index: -5.0. Wm2Front: 3717.0744999999997. Wm2Back: 1220.6495
# Linescan in process: 1axis_0.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_0.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_0.0_Scene0_Row3_Module7.csv
# Index: 0.0. Wm2Front: 1156.1905. Wm2Back: 336.87025
# Linescan in process: 1axis_5.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_5.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_5.0_Scene0_Row3_Module7.csv
# Index: 5.0. Wm2Front: 154186.25. Wm2Back: 40415.02
# Linescan in process: 1axis_10.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_10.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_10.0_Scene0_Row3_Module7.csv
# Index: 10.0. Wm2Front: 27341.045. Wm2Back: 7186.461000000001
# Linescan in process: 1axis_15.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_15.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_15.0_Scene0_Row3_Module7.csv
# Index: 15.0. Wm2Front: 31833.05. Wm2Back: 8009.2345000000005
# Linescan in process: 1axis_20.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_20.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_20.0_Scene0_Row3_Module7.csv
# Index: 20.0. Wm2Front: 126197.65. Wm2Back: 28494.235
# Linescan in process: 1axis_25.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_25.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_25.0_Scene0_Row3_Module7.csv
# Index: 25.0. Wm2Front: 56753.945. Wm2Back: 12456.085000000001
# Linescan in process: 1axis_30.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_30.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_30.0_Scene0_Row3_Module7.csv
# Index: 30.0. Wm2Front: 63676.59. Wm2Back: 12800.059999999998
# Linescan in process: 1axis_35.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_35.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_35.0_Scene0_Row3_Module7.csv
# Index: 35.0. Wm2Front: 96149.295. Wm2Back: 18211.36
# Linescan in process: 1axis_40.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_40.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_40.0_Scene0_Row3_Module7.csv
# Index: 40.0. Wm2Front: 74392.7. Wm2Back: 13045.650000000001
# Linescan in process: 1axis_45.0_Scene0_Row3_Module7_Front
# Linescan in process: 1axis_45.0_Scene0_Row3_Module7_Back
# Saved: results\irr_1axis_45.0_Scene0_Row3_Module7.csv
# Index: 45.0. Wm2Front: 402624.70000000007. Wm2Back: 62383.880000000005

# %%
temp = trackerdict.keys()
print(type(temp))
# Out:
# <class 'dict_keys'>

# %%
def print_ratio(deg):
    frontratio = trackerdictMTX[deg]['AnalysisObj'][0].Wm2Front.mean()/trackerdict[deg]['AnalysisObj'][0].Wm2Front.mean()
    backratio = trackerdictMTX[deg]['AnalysisObj'][0].Wm2Back.mean()/trackerdict[deg]['AnalysisObj'][0].Wm2Back.mean()
    print(f'GenMTX / Gencumsky front mean {deg} deg: {frontratio:0.2f}')
    print(f'GenMTX / Gencumsky back mean {deg} deg: {backratio:0.2f}')
    return(frontratio, backratio)
frontvals = []
mtx_sum = 0
gencum_sum = 0
backvals = []
for key in trackerdict.keys():
    mtx_sum += trackerdictMTX[key]['AnalysisObj'][0].Wm2Front.mean()
    gencum_sum += trackerdict[key]['AnalysisObj'][0].Wm2Front.mean()
    (front,back) = print_ratio(key)
    frontvals.append(front)
    backvals.append(back)
# Out:
# GenMTX / Gencumsky front mean -5.0 deg: 1.08
# GenMTX / Gencumsky back mean -5.0 deg: 1.18
# GenMTX / Gencumsky front mean -25.0 deg: 1.05
# GenMTX / Gencumsky back mean -25.0 deg: 1.04
# GenMTX / Gencumsky front mean -45.0 deg: 1.08
# GenMTX / Gencumsky back mean -45.0 deg: 1.06
# GenMTX / Gencumsky front mean -20.0 deg: 1.02
# GenMTX / Gencumsky back mean -20.0 deg: 1.05
# GenMTX / Gencumsky front mean 10.0 deg: 0.99
# GenMTX / Gencumsky back mean 10.0 deg: 1.00
# GenMTX / Gencumsky front mean 35.0 deg: 0.97
# GenMTX / Gencumsky back mean 35.0 deg: 1.02
# GenMTX / Gencumsky front mean 45.0 deg: 0.93
# GenMTX / Gencumsky back mean 45.0 deg: 0.98
# GenMTX / Gencumsky front mean 5.0 deg: 1.00
# GenMTX / Gencumsky back mean 5.0 deg: 1.03
# GenMTX / Gencumsky front mean 30.0 deg: 0.96
# GenMTX / Gencumsky back mean 30.0 deg: 1.00
# GenMTX / Gencumsky front mean 15.0 deg: 0.95
# GenMTX / Gencumsky back mean 15.0 deg: 1.00
# GenMTX / Gencumsky front mean -30.0 deg: 1.05
# GenMTX / Gencumsky back mean -30.0 deg: 1.03
# GenMTX / Gencumsky front mean 20.0 deg: 0.99
# GenMTX / Gencumsky back mean 20.0 deg: 0.99
# GenMTX / Gencumsky front mean 25.0 deg: 0.95
# GenMTX / Gencumsky back mean 25.0 deg: 1.02
# GenMTX / Gencumsky front mean -35.0 deg: 1.06
# GenMTX / Gencumsky back mean -35.0 deg: 1.05
# GenMTX / Gencumsky front mean -40.0 deg: 1.07
# GenMTX / Gencumsky back mean -40.0 deg: 1.06
# GenMTX / Gencumsky front mean -10.0 deg: 1.03
# GenMTX / Gencumsky back mean -10.0 deg: 1.03
# GenMTX / Gencumsky front mean 0.0 deg: 0.92
# GenMTX / Gencumsky back mean 0.0 deg: 0.93
# GenMTX / Gencumsky front mean -15.0 deg: 1.05
# GenMTX / Gencumsky back mean -15.0 deg: 1.08
# GenMTX / Gencumsky front mean 40.0 deg: 0.95
# GenMTX / Gencumsky back mean 40.0 deg: 0.98

# %%
print(f'Front Gencum sum: {gencum_sum:0.1f}. MTX sum: {mtx_sum:0.1f}. Ratio: {mtx_sum/gencum_sum:0.4f}')
# Out:
# Front Gencum sum: 1954942.6. MTX sum: 1961267.7. Ratio: 1.0032

# %%
print(np.mean(frontvals))
print(np.std(frontvals)/np.mean(frontvals))
print(np.mean(backvals))
print(np.std(backvals)/np.mean(backvals))
# Out:
# 1.0063063061246347
# 0.05097893031735242
# 1.0281182382827034
# 0.048079484769111176
